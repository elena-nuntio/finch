# %%
import tensorflow as tf
import numpy as np
from sklearn.metrics import classification_report

tf.logging.set_verbosity(tf.logging.INFO)

# %%
VOCAB_SIZE = 5000
MAX_LEN = 400
BATCH_SIZE = 32
EMBED_DIM = 50
FILTERS = 250
N_CLASS = 2
N_EPOCH = 2
LR = {'start': 5e-3, 'end': 5e-4, 'steps': 1500}

# %%
def forward(x, reuse, is_training):
    with tf.variable_scope('model', reuse=reuse):
        x = tf.contrib.layers.embed_sequence(x, VOCAB_SIZE, EMBED_DIM)
        x = tf.layers.dropout(x, 0.2, training=is_training)
        feat_map = []
        for k_size in [3, 4, 5]:
            _x = tf.layers.conv1d(x, FILTERS, k_size, activation=tf.nn.relu)
            _x = tf.layers.max_pooling1d(_x, _x.get_shape().as_list()[1], 1)
            _x = tf.reshape(_x, (tf.shape(x)[0], FILTERS))
            feat_map.append(_x)
        x = tf.concat(feat_map, -1)
        x = tf.layers.dense(x, FILTERS, tf.nn.relu)
        logits = tf.layers.dense(x, N_CLASS)
    return logits


def model_fn(features, labels, mode, params):
    logits = forward(features, reuse=False, is_training=True)
    preds = forward(features, reuse=True, is_training=False)
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        preds = tf.argmax(preds, -1)
        return tf.estimator.EstimatorSpec(mode, predictions=preds)
    
    if mode == tf.estimator.ModeKeys.TRAIN:
        global_step = tf.train.get_global_step()

        lr_op = tf.train.exponential_decay(
            LR['start'], global_step, LR['steps'], LR['end']/LR['start'])

        loss_op = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(
            logits=logits, labels=labels))

        train_op = tf.train.AdamOptimizer(lr_op).minimize(
            loss_op, global_step=global_step)

        lth = tf.train.LoggingTensorHook({'lr': lr_op}, every_n_iter=100)
        
        return tf.estimator.EstimatorSpec(
            mode=mode, loss=loss_op, train_op=train_op, training_hooks=[lth])

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.imdb.load_data(num_words=VOCAB_SIZE)
X_train = tf.keras.preprocessing.sequence.pad_sequences(X_train, MAX_LEN)
X_test = tf.keras.preprocessing.sequence.pad_sequences(X_test, MAX_LEN)

estimator = tf.estimator.Estimator(model_fn)

for _ in range(N_EPOCH):
    estimator.train(tf.estimator.inputs.numpy_input_fn(
        x = X_train, y = y_train,
        batch_size = BATCH_SIZE,
        shuffle = True))
    y_pred = np.array(list(estimator.predict(tf.estimator.inputs.numpy_input_fn(
        x = X_test,
        batch_size = BATCH_SIZE,
        shuffle = False))))
    print("\nValidation Accuracy: %.4f\n" % (y_pred==y_test).mean())
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpl9ayfqb9
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpl9ayfqb9', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1186af1d0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:Estimator's model_fn (<function model_fn at 0x108f99158>) includes params argument, but params are not passed to Estimator.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpl9ayfqb9/model.ckpt.
# INFO:tensorflow:loss = 0.694062, step = 1
# INFO:tensorflow:lr = 0.005
# INFO:tensorflow:global_step/sec: 8.14426
# INFO:tensorflow:loss = 0.5564747, step = 101 (12.280 sec)
# INFO:tensorflow:lr = 0.004288479 (12.280 sec)
# INFO:tensorflow:global_step/sec: 8.15477
# INFO:tensorflow:loss = 0.46165574, step = 201 (12.263 sec)
# INFO:tensorflow:lr = 0.0036782112 (12.262 sec)
# INFO:tensorflow:global_step/sec: 6.27242
# INFO:tensorflow:loss = 0.2116468, step = 301 (15.943 sec)
# INFO:tensorflow:lr = 0.0031547868 (15.943 sec)
# INFO:tensorflow:global_step/sec: 7.42873
# INFO:tensorflow:loss = 0.38365507, step = 401 (13.461 sec)
# INFO:tensorflow:lr = 0.0027058476 (13.461 sec)
# INFO:tensorflow:global_step/sec: 7.13264
# INFO:tensorflow:loss = 0.32155457, step = 501 (14.020 sec)
# INFO:tensorflow:lr = 0.0023207942 (14.020 sec)
# INFO:tensorflow:global_step/sec: 6.77474
# INFO:tensorflow:loss = 0.25030518, step = 601 (14.761 sec)
# INFO:tensorflow:lr = 0.0019905358 (14.760 sec)
# INFO:tensorflow:global_step/sec: 7.26802
# INFO:tensorflow:loss = 0.11547301, step = 701 (13.759 sec)
# INFO:tensorflow:lr = 0.0017072745 (13.758 sec)
# INFO:tensorflow:Saving checkpoints for 782 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpl9ayfqb9/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.056810774.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpl9ayfqb9/model.ckpt-782
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Validation Accuracy: 0.8986
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpl9ayfqb9/model.ckpt-782
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 783 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpl9ayfqb9/model.ckpt.
# INFO:tensorflow:loss = 0.094445795, step = 783
# INFO:tensorflow:lr = 0.0015053472
# INFO:tensorflow:global_step/sec: 7.11253
# INFO:tensorflow:loss = 0.2306277, step = 883 (14.061 sec)
# INFO:tensorflow:lr = 0.00129113 (14.060 sec)
# INFO:tensorflow:global_step/sec: 8.31576
# INFO:tensorflow:loss = 0.08843993, step = 983 (12.026 sec)
# INFO:tensorflow:lr = 0.001107397 (12.026 sec)
# INFO:tensorflow:global_step/sec: 6.79989
# INFO:tensorflow:loss = 0.20799604, step = 1083 (14.706 sec)
# INFO:tensorflow:lr = 0.00094980985 (14.706 sec)
# INFO:tensorflow:global_step/sec: 8.42359
# INFO:tensorflow:loss = 0.22056979, step = 1183 (11.871 sec)
# INFO:tensorflow:lr = 0.00081464805 (11.871 sec)
# INFO:tensorflow:global_step/sec: 7.82589
# INFO:tensorflow:loss = 0.25905767, step = 1283 (12.778 sec)
# INFO:tensorflow:lr = 0.0006987203 (12.778 sec)
# INFO:tensorflow:global_step/sec: 6.57011
# INFO:tensorflow:loss = 0.20813067, step = 1383 (15.220 sec)
# INFO:tensorflow:lr = 0.00059928955 (15.220 sec)
# INFO:tensorflow:global_step/sec: 7.50836
# INFO:tensorflow:loss = 0.1095005, step = 1483 (13.319 sec)
# INFO:tensorflow:lr = 0.00051400816 (13.319 sec)
# INFO:tensorflow:Saving checkpoints for 1564 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpl9ayfqb9/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.08816059.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpl9ayfqb9/model.ckpt-1564
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Validation Accuracy: 0.8964
