# %%
import tensorflow as tf
import numpy as np
from sklearn.metrics import classification_report

# %%
VOCAB_SIZE = 10000
MAX_LEN = 500
HIDDEN_DIM = 50
POS_DIM = 20
BATCH_SIZE = 32
LR = {'start': 5e-3, 'end': 5e-4, 'steps': 1500}
N_EPOCH = 2
N_CLASS = 2

# %%
def embed_seq(x, vocab_sz, embed_dim, name):
    embedding = tf.get_variable(name, [vocab_sz, embed_dim])
    return tf.nn.embedding_lookup(embedding, x)


def position_embedding(inputs):
    T = inputs.get_shape().as_list()[1]
    x = tf.range(T)                            # (T)
    x = tf.expand_dims(x, 0)                   # (1, T)
    x = tf.tile(x, [tf.shape(inputs)[0], 1])   # (N, T)
    return embed_seq(x, T, POS_DIM, 'position_embedding')


def forward(inputs, reuse, is_training):
    with tf.variable_scope('model', reuse=reuse):
        V = embed_seq(inputs, VOCAB_SIZE, HIDDEN_DIM, 'word_embedding')
        x = tf.concat((V, position_embedding(V)), -1)
        x = tf.layers.dropout(x, 0.2, training=is_training)
        
        # alignment
        align = tf.squeeze(tf.layers.dense(x, 1, tf.tanh), -1)
        # masking
        masks = tf.sign(inputs)
        paddings = tf.fill(tf.shape(align), float('-inf'))
        align = tf.where(tf.equal(masks, 0), paddings, align)
        # probability
        align = tf.expand_dims(tf.nn.softmax(align), -1)
        # weighted sum
        x = tf.squeeze(tf.matmul(tf.transpose(V, [0,2,1]), align), -1)
        
        logits = tf.layers.dense(x, N_CLASS)
    return logits


def model_fn(features, labels, mode, params):
    logits = forward(features, reuse=False, is_training=True)
    preds = forward(features, reuse=True, is_training=False)
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        preds = tf.argmax(preds, -1)
        return tf.estimator.EstimatorSpec(mode, predictions=preds)
    
    if mode == tf.estimator.ModeKeys.TRAIN:
        global_step = tf.train.get_global_step()

        lr_op = tf.train.exponential_decay(
            LR['start'], global_step, LR['steps'], LR['end']/LR['start'])

        loss_op = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(
            logits=logits, labels=labels))

        train_op = tf.train.AdamOptimizer(lr_op).minimize(
            loss_op, global_step=global_step)

        lth = tf.train.LoggingTensorHook({'lr': lr_op}, every_n_iter=100)
        
        return tf.estimator.EstimatorSpec(
            mode=mode, loss=loss_op, train_op=train_op, training_hooks=[lth])

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.imdb.load_data(num_words=VOCAB_SIZE)
X_train = tf.keras.preprocessing.sequence.pad_sequences(X_train, MAX_LEN, padding='post')
X_test = tf.keras.preprocessing.sequence.pad_sequences(X_test, MAX_LEN, padding='post')

estimator = tf.estimator.Estimator(model_fn)

for _ in range(N_EPOCH):
    estimator.train(tf.estimator.inputs.numpy_input_fn(
        x = X_train, y = y_train,
        batch_size = BATCH_SIZE,
        shuffle = True))
    y_pred = np.fromiter(estimator.predict(tf.estimator.inputs.numpy_input_fn(
        x = X_test,
        batch_size = BATCH_SIZE,
        shuffle = False)), np.int32)
    print("\nValidation Accuracy: %.4f\n" % (y_pred==y_test).mean())
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmppt338u7p
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmppt338u7p', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x11756b1d0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:Estimator's model_fn (<function model_fn at 0x117a60840>) includes params argument, but params are not passed to Estimator.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmppt338u7p/model.ckpt.
# INFO:tensorflow:loss = 0.69369256, step = 1
# INFO:tensorflow:lr = 0.005
# INFO:tensorflow:global_step/sec: 59.1911
# INFO:tensorflow:loss = 0.4158855, step = 101 (1.691 sec)
# INFO:tensorflow:lr = 0.004288479 (1.690 sec)
# INFO:tensorflow:global_step/sec: 62.7418
# INFO:tensorflow:loss = 0.28545153, step = 201 (1.594 sec)
# INFO:tensorflow:lr = 0.0036782112 (1.594 sec)
# INFO:tensorflow:global_step/sec: 59.6244
# INFO:tensorflow:loss = 0.23272654, step = 301 (1.677 sec)
# INFO:tensorflow:lr = 0.0031547868 (1.677 sec)
# INFO:tensorflow:global_step/sec: 60.9211
# INFO:tensorflow:loss = 0.30133826, step = 401 (1.641 sec)
# INFO:tensorflow:lr = 0.0027058476 (1.642 sec)
# INFO:tensorflow:global_step/sec: 58.1459
# INFO:tensorflow:loss = 0.30294615, step = 501 (1.720 sec)
# INFO:tensorflow:lr = 0.0023207942 (1.720 sec)
# INFO:tensorflow:global_step/sec: 49.3247
# INFO:tensorflow:loss = 0.2239761, step = 601 (2.027 sec)
# INFO:tensorflow:lr = 0.0019905358 (2.028 sec)
# INFO:tensorflow:global_step/sec: 56.6714
# INFO:tensorflow:loss = 0.10413474, step = 701 (1.765 sec)
# INFO:tensorflow:lr = 0.0017072745 (1.764 sec)
# INFO:tensorflow:Saving checkpoints for 782 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmppt338u7p/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.15102938.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmppt338u7p/model.ckpt-782
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Validation Accuracy: 0.8923
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmppt338u7p/model.ckpt-782
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 783 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmppt338u7p/model.ckpt.
# INFO:tensorflow:loss = 0.19695093, step = 783
# INFO:tensorflow:lr = 0.0015053472
# INFO:tensorflow:global_step/sec: 57.992
# INFO:tensorflow:loss = 0.083605036, step = 883 (1.726 sec)
# INFO:tensorflow:lr = 0.00129113 (1.726 sec)
# INFO:tensorflow:global_step/sec: 56.3927
# INFO:tensorflow:loss = 0.15806302, step = 983 (1.773 sec)
# INFO:tensorflow:lr = 0.001107397 (1.774 sec)
# INFO:tensorflow:global_step/sec: 58.1565
# INFO:tensorflow:loss = 0.12529317, step = 1083 (1.720 sec)
# INFO:tensorflow:lr = 0.00094980985 (1.720 sec)
# INFO:tensorflow:global_step/sec: 58.4768
# INFO:tensorflow:loss = 0.11247274, step = 1183 (1.709 sec)
# INFO:tensorflow:lr = 0.00081464805 (1.709 sec)
# INFO:tensorflow:global_step/sec: 58.2503
# INFO:tensorflow:loss = 0.16413558, step = 1283 (1.717 sec)
# INFO:tensorflow:lr = 0.0006987203 (1.717 sec)
# INFO:tensorflow:global_step/sec: 60.5418
# INFO:tensorflow:loss = 0.24005078, step = 1383 (1.652 sec)
# INFO:tensorflow:lr = 0.00059928955 (1.652 sec)
# INFO:tensorflow:global_step/sec: 60.3773
# INFO:tensorflow:loss = 0.16226158, step = 1483 (1.656 sec)
# INFO:tensorflow:lr = 0.00051400816 (1.656 sec)
# INFO:tensorflow:Saving checkpoints for 1564 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmppt338u7p/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.24146852.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmppt338u7p/model.ckpt-1564
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Validation Accuracy: 0.8884
