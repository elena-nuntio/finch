# %%
import tensorflow as tf
import numpy as np
from sklearn.metrics import classification_report

# %%
VOCAB_SIZE = 10000
MAX_LEN = 400
HIDDEN_DIM = 50
BATCH_SIZE = 32
LR = {'start': 5e-3, 'end': 5e-4, 'steps': 1500}
N_EPOCH = 2
N_CLASS = 2

# %%
def embed_seq(x, vocab_sz, embed_dim, name):
    embedding = tf.get_variable(name, [vocab_sz, embed_dim])
    return tf.nn.embedding_lookup(embedding, x)


def position_embedding(inputs, repr_dim=HIDDEN_DIM):
    T = inputs.get_shape().as_list()[1]
    x = tf.range(T)                            # (T)
    x = tf.expand_dims(x, 0)                   # (1, T)
    x = tf.tile(x, [tf.shape(inputs)[0], 1])   # (N, T)
    return embed_seq(x, T, repr_dim, 'position_embedding')


def google_position_encoding(inputs, repr_dim=HIDDEN_DIM):
    T = inputs.get_shape().as_list()[1]
    pos_idx = tf.tile(tf.expand_dims(tf.range(T), 0), [tf.shape(inputs)[0], 1])

    pos_enc = np.array(
        [[pos / np.power(10000, 2*i/repr_dim) for i in range(repr_dim)] for pos in range(T)])
    pos_enc[:, 0::2] = np.sin(pos_enc[:, 0::2])  
    pos_enc[:, 1::2] = np.cos(pos_enc[:, 1::2]) 

    lookup_table = tf.convert_to_tensor(pos_enc, tf.float32)
    return tf.nn.embedding_lookup(lookup_table, pos_idx)


def importance_weighting(x):
    x = tf.layers.conv1d(x,
                         filters=1,
                         kernel_size=5,
                         activation=tf.nn.relu,
                         padding='same')
    return tf.squeeze(x, -1)


def forward(inputs, reuse, is_training):
    with tf.variable_scope('model', reuse=reuse):
        V = embed_seq(inputs, VOCAB_SIZE, HIDDEN_DIM, 'word_embedding')
        x = V + google_position_encoding(inputs)
        x = tf.layers.dropout(x, 0.1, training=is_training)
        
        # alignment
        align = importance_weighting(x)
        # masking
        masks = tf.sign(inputs)
        paddings = tf.fill(tf.shape(align), float('-inf'))
        align = tf.where(tf.equal(masks, 0), paddings, align)
        # probability
        align = tf.expand_dims(tf.nn.softmax(align), -1)
        # weighted sum
        x = tf.squeeze(tf.matmul(tf.transpose(V, [0,2,1]), align), -1)
        
        logits = tf.layers.dense(x, N_CLASS)
    return logits


def model_fn(features, labels, mode, params):
    logits = forward(features, reuse=False, is_training=True)
    preds = forward(features, reuse=True, is_training=False)
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        preds = tf.argmax(preds, -1)
        return tf.estimator.EstimatorSpec(mode, predictions=preds)
    
    if mode == tf.estimator.ModeKeys.TRAIN:
        global_step = tf.train.get_global_step()

        lr_op = tf.train.exponential_decay(
            LR['start'], global_step, LR['steps'], LR['end']/LR['start'])

        loss_op = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(
            logits=logits, labels=labels))

        train_op = tf.train.AdamOptimizer(lr_op).minimize(
            loss_op, global_step=global_step)

        lth = tf.train.LoggingTensorHook({'lr': lr_op}, every_n_iter=100)
        
        return tf.estimator.EstimatorSpec(
            mode=mode, loss=loss_op, train_op=train_op, training_hooks=[lth])

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.imdb.load_data(num_words=VOCAB_SIZE)
X_train = tf.keras.preprocessing.sequence.pad_sequences(X_train, MAX_LEN, padding='post')
X_test = tf.keras.preprocessing.sequence.pad_sequences(X_test, MAX_LEN, padding='post')

estimator = tf.estimator.Estimator(model_fn)

for _ in range(N_EPOCH):
    estimator.train(tf.estimator.inputs.numpy_input_fn(
        x = X_train, y = y_train,
        batch_size = BATCH_SIZE,
        shuffle = True))
    y_pred = np.fromiter(estimator.predict(tf.estimator.inputs.numpy_input_fn(
        x = X_test,
        batch_size = BATCH_SIZE,
        shuffle = False)), np.int32)
    print("\nValidation Accuracy: %.4f\n" % (y_pred==y_test).mean())
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpcvaw9za_
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpcvaw9za_', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x122045be0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:Estimator's model_fn (<function model_fn at 0x12263cea0>) includes params argument, but params are not passed to Estimator.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpcvaw9za_/model.ckpt.
# INFO:tensorflow:loss = 0.6934262, step = 1
# INFO:tensorflow:lr = 0.005
# INFO:tensorflow:global_step/sec: 43.5955
# INFO:tensorflow:loss = 0.4045486, step = 101 (2.295 sec)
# INFO:tensorflow:lr = 0.004288479 (2.295 sec)
# INFO:tensorflow:global_step/sec: 46.2955
# INFO:tensorflow:loss = 0.16195518, step = 201 (2.160 sec)
# INFO:tensorflow:lr = 0.0036782112 (2.160 sec)
# INFO:tensorflow:global_step/sec: 45.8026
# INFO:tensorflow:loss = 0.26142108, step = 301 (2.183 sec)
# INFO:tensorflow:lr = 0.0031547868 (2.183 sec)
# INFO:tensorflow:global_step/sec: 42.9731
# INFO:tensorflow:loss = 0.27183893, step = 401 (2.327 sec)
# INFO:tensorflow:lr = 0.0027058476 (2.327 sec)
# INFO:tensorflow:global_step/sec: 42.0712
# INFO:tensorflow:loss = 0.17777859, step = 501 (2.377 sec)
# INFO:tensorflow:lr = 0.0023207942 (2.377 sec)
# INFO:tensorflow:global_step/sec: 43.3305
# INFO:tensorflow:loss = 0.24411525, step = 601 (2.308 sec)
# INFO:tensorflow:lr = 0.0019905358 (2.308 sec)
# INFO:tensorflow:global_step/sec: 44.0313
# INFO:tensorflow:loss = 0.2794447, step = 701 (2.271 sec)
# INFO:tensorflow:lr = 0.0017072745 (2.271 sec)
# INFO:tensorflow:Saving checkpoints for 782 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpcvaw9za_/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.2649346.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpcvaw9za_/model.ckpt-782
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Validation Accuracy: 0.9082
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpcvaw9za_/model.ckpt-782
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 783 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpcvaw9za_/model.ckpt.
# INFO:tensorflow:loss = 0.14775614, step = 783
# INFO:tensorflow:lr = 0.0015053472
# INFO:tensorflow:global_step/sec: 42.8616
# INFO:tensorflow:loss = 0.092342794, step = 883 (2.334 sec)
# INFO:tensorflow:lr = 0.00129113 (2.334 sec)
# INFO:tensorflow:global_step/sec: 43.7867
# INFO:tensorflow:loss = 0.16018596, step = 983 (2.284 sec)
# INFO:tensorflow:lr = 0.001107397 (2.284 sec)
# INFO:tensorflow:global_step/sec: 44.6342
# INFO:tensorflow:loss = 0.20826614, step = 1083 (2.241 sec)
# INFO:tensorflow:lr = 0.00094980985 (2.241 sec)
# INFO:tensorflow:global_step/sec: 42.6652
# INFO:tensorflow:loss = 0.12573984, step = 1183 (2.344 sec)
# INFO:tensorflow:lr = 0.00081464805 (2.344 sec)
# INFO:tensorflow:global_step/sec: 45.4778
# INFO:tensorflow:loss = 0.14379251, step = 1283 (2.199 sec)
# INFO:tensorflow:lr = 0.0006987203 (2.199 sec)
# INFO:tensorflow:global_step/sec: 42.3899
# INFO:tensorflow:loss = 0.08070489, step = 1383 (2.359 sec)
# INFO:tensorflow:lr = 0.00059928955 (2.359 sec)
# INFO:tensorflow:global_step/sec: 44.695
# INFO:tensorflow:loss = 0.09584296, step = 1483 (2.238 sec)
# INFO:tensorflow:lr = 0.00051400816 (2.237 sec)
# INFO:tensorflow:Saving checkpoints for 1564 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpcvaw9za_/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0481242.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpcvaw9za_/model.ckpt-1564
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Validation Accuracy: 0.9078
