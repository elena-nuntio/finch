# %%
import tensorflow as tf
import numpy as np

# %%
params = {
    'batch_size': 128,
    'text_iter_step': 25,
    'seq_len': 400,
    'hidden_dim': 128,
    'n_layers': 2,
    'beam_width': 5,
    'display_step': 10,
    'generate_step': 100,
    'clip_norm': 5.0,
}

# %%
def parse_text(file_path):
    with open(file_path) as f:
        text = f.read()
    
    char2idx = {c: i+3 for i, c in enumerate(set(text))}
    char2idx['<pad>'] = 0
    char2idx['<start>'] = 1
    char2idx['<end>'] = 2
    
    ints = np.array([char2idx[char] for char in list(text)])
    return ints, char2idx

def next_batch(ints):
    len_win = params['seq_len'] * params['batch_size']
    for i in range(0, len(ints)-len_win, params['text_iter_step']):
        clip = ints[i: i+len_win]
        yield clip.reshape([params['batch_size'], params['seq_len']])
        
def input_fn(ints):
    dataset = tf.data.Dataset.from_generator(
        lambda: next_batch(ints), tf.int32, tf.TensorShape([None, params['seq_len']]))
    iterator = dataset.make_one_shot_iterator()
    return iterator.get_next()

# %%
def start_sent(x):
    _x = tf.fill([tf.shape(x)[0], 1], params['char2idx']['<start>'])
    return tf.concat([_x, x], 1)

def end_sent(x):
    _x = tf.fill([tf.shape(x)[0], 1], params['char2idx']['<end>'])
    return tf.concat([x, _x], 1)

def cell_fn():
    return tf.nn.rnn_cell.ResidualWrapper(
        tf.nn.rnn_cell.GRUCell(params['hidden_dim'],
            kernel_initializer=tf.orthogonal_initializer()))
  
def multi_cell_fn():
    return tf.nn.rnn_cell.MultiRNNCell([cell_fn() for _ in range(params['n_layers'])])

def clip_grads(loss):
    variables = tf.trainable_variables()
    grads = tf.gradients(loss, variables)
    clipped_grads, _ = tf.clip_by_global_norm(grads, params['clip_norm'])
    return zip(clipped_grads, variables)

# %%
def forward(inputs):
    cells = multi_cell_fn()
    batch_sz = tf.shape(inputs)[0]
    
    with tf.variable_scope('main', reuse=False):
        embedding = tf.get_variable('lookup_table', [params['vocab_size'], params['hidden_dim']])

        helper = tf.contrib.seq2seq.TrainingHelper(
            inputs = tf.nn.embedding_lookup(embedding, inputs),
            sequence_length = tf.count_nonzero(inputs, 1, dtype=tf.int32))
        
        decoder = tf.contrib.seq2seq.BasicDecoder(
            cell = cells,
            helper = helper,
            initial_state = cells.zero_state(batch_sz, tf.float32),
            output_layer = tf.layers.Dense(params['vocab_size']))
        
        decoder_output, _, _ = tf.contrib.seq2seq.dynamic_decode(
            decoder = decoder)
        
        logits = decoder_output.rnn_output
        
    with tf.variable_scope('main', reuse=True):
        decoder = tf.contrib.seq2seq.BeamSearchDecoder(
            cell = cells,
            embedding = tf.get_variable('lookup_table'),
            start_tokens = tf.tile(tf.constant(
                [params['char2idx']['<start>']], dtype=tf.int32), [1]),
            end_token = params['char2idx']['<end>'],
            initial_state = tf.contrib.seq2seq.tile_batch(
                cells.zero_state(1, tf.float32), params['beam_width']),
            beam_width = params['beam_width'],
            output_layer = tf.layers.Dense(params['vocab_size'], _reuse=True))
        
        decoder_out, _, _ = tf.contrib.seq2seq.dynamic_decode(
            decoder = decoder,
            maximum_iterations = params['seq_len'])
        
        predict = decoder_out.predicted_ids[:, :, 0]

    return logits, predict

# %%
ints, params['char2idx'] = parse_text('../temp/anna.txt')
params['vocab_size'] = len(params['char2idx'])
params['idx2char'] = {i: c for c, i in params['char2idx'].items()}
print('Vocabulary size:', params['vocab_size'])

ops = {}
X = input_fn(ints)

logits, ops['generate'] = forward(start_sent(X))

ops['global_step'] = tf.Variable(0, trainable=False)

targets = end_sent(X)
ops['loss'] = tf.reduce_mean(tf.contrib.seq2seq.sequence_loss(
    logits = logits,
    targets = targets,
    weights = tf.to_float(tf.ones_like(targets))))

ops['train'] = tf.train.AdamOptimizer().apply_gradients(
    clip_grads(ops['loss']), global_step=ops['global_step'])
# Out:
# Vocabulary size: 86

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())
while True:
    try:
        sess.run(ops['train'])
    except tf.errors.OutOfRangeError:
        break
    else:
        step = sess.run(ops['global_step'])
        if step % params['display_step'] == 0 or step == 1:
            loss = sess.run(ops['loss'])
            print("Step %d | Loss %.3f" % (step, loss))
        if step % params['generate_step'] == 0 and step > 1:
            ints = sess.run(ops['generate'])[0]
            print('\n'+''.join([params['idx2char'][i] for i in ints])+'\n')
# Out:
# Step 1 | Loss 4.407
# Step 10 | Loss 3.521
# Step 20 | Loss 3.109
# Step 30 | Loss 3.026
# Step 40 | Loss 2.935
# Step 50 | Loss 2.818
# Step 60 | Loss 2.681
# Step 70 | Loss 2.564
# Step 80 | Loss 2.478
# Step 90 | Loss 2.411
# Step 100 | Loss 2.356
#
# ed the the and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and the s
#
# Step 110 | Loss 2.305
# Step 120 | Loss 2.259
# Step 130 | Loss 2.215
# Step 140 | Loss 2.171
# Step 150 | Loss 2.130
# Step 160 | Loss 2.089
# Step 170 | Loss 2.049
# Step 180 | Loss 2.006
# Step 190 | Loss 1.966
# Step 200 | Loss 1.930
#
# e the said to the could the could the could of the could and the could the could the could the could the could and the could and the could and the could and the could and the could and the could and the could and the could and the could and the could and the could and the could and the could and the could and the could and the could and the could and the could and the could and the could and that
#
# Step 210 | Loss 1.894
# Step 220 | Loss 1.860
# Step 230 | Loss 1.829
# Step 240 | Loss 1.795
# Step 250 | Loss 1.762
# Step 260 | Loss 1.729
# Step 270 | Loss 1.697
# Step 280 | Loss 1.666
# Step 290 | Loss 1.637
# Step 300 | Loss 1.609
#
#  the said, and with the could not on the could not on the could not on the could not on the could not on the could not on the could not on the could not on the could not on the could not on the could not on the could not on the could not on the could not on the could not on the could not on the could not on the could not on the could not on the could not on the could not on the could not on the co
#
# Step 310 | Loss 1.580
# Step 320 | Loss 1.551
# Step 330 | Loss 1.523
# Step 340 | Loss 1.496
# Step 350 | Loss 1.468
# Step 360 | Loss 1.442
# Step 370 | Loss 1.413
# Step 380 | Loss 1.387
# Step 390 | Loss 1.359
# Step 400 | Loss 1.333
#
#  his handsome that he had been him, and he went on the door.
#
# Stepan Arkadyevitch could not go on the professor, and that it was in the professor, and that it was in the professor, and that it was in the professor, and that it was in the professor, and that it was in the professor, and that it was in the professor, and that it was in the professor, and that it was in the professor, and that he was
#
# Step 410 | Loss 1.307
# Step 420 | Loss 1.286
# Step 430 | Loss 1.262
# Step 440 | Loss 1.235
# Step 450 | Loss 1.208
# Step 460 | Loss 1.183
# Step 470 | Loss 1.159
# Step 480 | Loss 1.132
# Step 490 | Loss 1.108
# Step 500 | Loss 1.083
#
#  his brother with the country.
#
# "Well, he said, and that it was impossible to him, and that it was in love with the professor, and that it was impossible in the professor, and that he would be an offer of his friends, and with his brother with the professor, and that it was impossible to the professor, and that it was impossible in the professor, and that he would be an offer of his friends, and t
#
# Step 510 | Loss 1.059
# Step 520 | Loss 1.037
# Step 530 | Loss 1.008
# Step 540 | Loss 0.988
# Step 550 | Loss 0.958
# Step 560 | Loss 0.939
# Step 570 | Loss 0.916
# Step 580 | Loss 0.887
# Step 590 | Loss 0.879
# Step 600 | Loss 0.841
#
# ing herself, with his characteristic of the conversation with the country.
#
# Stepan Arkadyevitch could never consciousness of existence, and that he would never consciousness of existence, and that he would never consciousness of existence, and that he would never consciousness of existence, and that he would never consciousness of existence, and that he would never consciousness of existence, and
#
# Step 610 | Loss 0.822
# Step 620 | Loss 0.802
# Step 630 | Loss 0.777
# Step 640 | Loss 0.756
# Step 650 | Loss 0.736
# Step 660 | Loss 0.717
# Step 670 | Loss 0.698
# Step 680 | Loss 0.683
# Step 690 | Loss 0.663
# Step 700 | Loss 0.642
#
# ing herself, she went out of his friends, and that he would never could not very herself to go out of the childrent what he had come to Oblonsky with the country.
#
# Stepan Arkadyevitch could never could not very herself to go out of the childrent what he had come to Oblonsky with the country.
#
# Stepan Arkadyevitch could never could not very herself to go out of the childrent what he had come to Mosc
#
# Step 710 | Loss 0.627
# Step 720 | Loss 0.610
# Step 730 | Loss 0.589
# Step 740 | Loss 0.576
# Step 750 | Loss 0.556
# Step 760 | Loss 0.558
# Step 770 | Loss 0.538
# Step 780 | Loss 0.534
# Step 790 | Loss 0.520
# Step 800 | Loss 0.505
#
# there with to the professor
# had gone with the Shtcherbatskys' house, and
# he was in love with the country.
#
# Stepan Arkadyevitch could never could never would have go on his brother, and the Shtcherbatskys' house that he saw for the first that hearn him, as though someone out looking at her, he askeady him that it was impossible to do anything, and no litten out when he was this, and skating his hea
#
# Step 810 | Loss 0.498
# Step 820 | Loss 0.488
# Step 830 | Loss 0.521
# Step 840 | Loss 0.473
# Step 850 | Loss 0.470
# Step 860 | Loss 0.466
# Step 870 | Loss 0.455
# Step 880 | Loss 0.444
# Step 890 | Loss 0.435
# Step 900 | Loss 0.429
#
# n the same out of the room. "Matvey says she will come round; but how? I
# don't see the least chance of it."
#
#
#
#
# Chapper she was in the childrem, and he was in love with the Shtcherbatskys' house that he saw for the first
# time that inner life of an old, noble, cultivated, and honorable family
# of which he had been discussion for an instant's all the conversation with the professor, he said.
#
# Stepan
#
# Step 910 | Loss 0.433
# Step 920 | Loss 0.426
# Step 930 | Loss 0.422
# Step 940 | Loss 0.416
# Step 950 | Loss 0.418
# Step 960 | Loss 0.406
# Step 970 | Loss 0.402
# Step 980 | Loss 0.432
# Step 990 | Loss 0.409
# Step 1000 | Loss 0.398
#
# there with the most
# horrible that was over of the liking of the room. Stepan Arkadyevitch made his elder half-brother, Koznishev."
#
# "Delighted," said Stepan Arkadyevitch, and not
# content with shaking hands, he kissed his friend<end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end>
#
# Step 1010 | Loss 0.459
# Step 1020 | Loss 0.408
# Step 1030 | Loss 0.393
# Step 1040 | Loss 0.392
# Step 1050 | Loss 0.387
# Step 1060 | Loss 0.397
# Step 1070 | Loss 0.397
# Step 1080 | Loss 0.407
# Step 1090 | Loss 0.404
# Step 1100 | Loss 0.415
#
# oud
# the country, the fort of her seening in the professor, and the smile of chilly friendliness
# he always had for everyone, and introducing him to the professor, went
# on with the conversation.
#
# A little man in spectacles, with a narrow forehead, tore himself from
# the discussion for an instant to greet Levin, and then went on talking
# without being
# tome cheld could don't untere to
# author.
#
# "I don't
#
# Step 1110 | Loss 0.406
# Step 1120 | Loss 0.403
# Step 1130 | Loss 0.436
# Step 1140 | Loss 0.433
# Step 1150 | Loss 0.419
# Step 1160 | Loss 0.416
# Step 1170 | Loss 0.433
# Step 1180 | Loss 0.439
# Step 1190 | Loss 0.428
# Step 1200 | Loss 0.433
#
#  his brother-in-law, Kitty, gave a other differently.
#
# "You uried to make out the Shtcherbatskys' house that he saw for the first
# time that inner life of an old, noble, cultivated, and honorable family
# of which he had been deprived by the death of his father and mother. All
# the members of that family, especially the feminine half, were pictured
# by him, as it were, wrapped about with a mysterious p
# Step 1210 | Loss 0.424
# Step 1220 | Loss 0.467
# Step 1230 | Loss 0.438
# Step 1240 | Loss 0.430
# Step 1250 | Loss 0.434
